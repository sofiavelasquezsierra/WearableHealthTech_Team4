# %%
import os, glob

print("CloudStorage contents:")
print(os.listdir(os.path.expanduser("~/Library/CloudStorage")))

print("\nPossible Box roots:")
print(glob.glob(os.path.expanduser("~/Library/CloudStorage/Box*")))

import os
import pandas as pd

BOX_ROOT = os.path.expanduser("~/Library/CloudStorage/Box-Box")
# Out:
# CloudStorage contents:
# ['.DS_Store', 'Box-Box']
#
# Possible Box roots:
# ['/Users/aprillin/Library/CloudStorage/Box-Box']

# %%
import numpy as np
import pandas as pd
import Levenshtein 
import matplotlib.pyplot as plt
import seaborn as sns
import os
BOX_ROOT = os.path.expanduser("~/Library/CloudStorage/Box-Box")
DATA_PATH=os.path.join(
    BOX_ROOT,
    "WHT Datasets",
    "00_raw",
    "RealWorldHAR",
    "realworld2016_dataset",
    "proband14",
    "data")

# %%
# --- Gyroscope waist ---
gyro_motion_waist_path = os.path.join(DATA_PATH, "Gyroscope_walking_waist.csv")
gyro_motion_waist = pd.read_csv(gyro_motion_waist_path)
gyro_suffix = os.path.basename(gyro_motion_waist_path).replace(".csv","").split("_")[-1]
gyro_motion_waist.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_waist.columns
]

# --- Accelerometer waist ---
acc_motion_waist_path = os.path.join(DATA_PATH, "acc_walking_waist.csv")
acc_motion_waist = pd.read_csv(acc_motion_waist_path)
acc_suffix = os.path.basename(acc_motion_waist_path).replace(".csv","").split("_")[-1]
acc_motion_waist.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_waist.columns
]

# --- Gyroscope forearm ---
gyro_motion_forearm_path = os.path.join(DATA_PATH, "Gyroscope_walking_forearm.csv")
gyro_motion_forearm = pd.read_csv(gyro_motion_forearm_path)
gyro_suffix = os.path.basename(gyro_motion_forearm_path).replace(".csv","").split("_")[-1]
gyro_motion_forearm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_forearm.columns
]

# --- Accelerometer forearm ---
acc_motion_forearm_path = os.path.join(DATA_PATH, "acc_walking_forearm.csv")
acc_motion_forearm = pd.read_csv(acc_motion_forearm_path)
acc_suffix = os.path.basename(acc_motion_forearm_path).replace(".csv","").split("_")[-1]
acc_motion_forearm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_forearm.columns
]

# --- Gyroscope head ---
gyro_motion_head_path = os.path.join(DATA_PATH, "Gyroscope_walking_head.csv")
gyro_motion_head = pd.read_csv(gyro_motion_head_path)
gyro_suffix = os.path.basename(gyro_motion_head_path).replace(".csv","").split("_")[-1]
gyro_motion_head.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_head.columns
]

# --- Accelerometer head ---
acc_motion_head_path = os.path.join(DATA_PATH, "acc_walking_head.csv")
acc_motion_head = pd.read_csv(acc_motion_head_path)
acc_suffix = os.path.basename(acc_motion_head_path).replace(".csv","").split("_")[-1]
acc_motion_head.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_head.columns
]

# --- Gyroscope chest ---
gyro_motion_chest_path = os.path.join(DATA_PATH, "Gyroscope_walking_chest.csv")
gyro_motion_chest = pd.read_csv(gyro_motion_chest_path)
gyro_suffix = os.path.basename(gyro_motion_chest_path).replace(".csv","").split("_")[-1]
gyro_motion_chest.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_chest.columns
]

# --- Accelerometer forearm ---
acc_motion_chest_path = os.path.join(DATA_PATH, "acc_walking_chest.csv")
acc_motion_chest = pd.read_csv(acc_motion_chest_path)
acc_suffix = os.path.basename(acc_motion_chest_path).replace(".csv","").split("_")[-1]
acc_motion_chest.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_chest.columns
]

# --- Gyroscope shin ---
gyro_motion_shin_path = os.path.join(DATA_PATH, "Gyroscope_walking_shin.csv")
gyro_motion_shin = pd.read_csv(gyro_motion_shin_path)
gyro_suffix = os.path.basename(gyro_motion_shin_path).replace(".csv","").split("_")[-1]
gyro_motion_shin.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_shin.columns
]

# --- Accelerometer shin ---
acc_motion_shin_path = os.path.join(DATA_PATH, "acc_walking_shin.csv")
acc_motion_shin = pd.read_csv(acc_motion_shin_path)
acc_suffix = os.path.basename(acc_motion_shin_path).replace(".csv","").split("_")[-1]
acc_motion_shin.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_shin.columns
]

# --- Gyroscope upperearm ---
gyro_motion_upperarm_path = os.path.join(DATA_PATH, "Gyroscope_walking_upperarm.csv")
gyro_motion_upperarm = pd.read_csv(gyro_motion_upperarm_path)
gyro_suffix = os.path.basename(gyro_motion_upperarm_path).replace(".csv","").split("_")[-1]
gyro_motion_upperarm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_upperarm.columns
]

# --- Accelerometer upperarm ---
acc_motion_upperarm_path = os.path.join(DATA_PATH, "acc_walking_upperarm.csv")
acc_motion_upperarm = pd.read_csv(acc_motion_upperarm_path)
acc_suffix = os.path.basename(acc_motion_upperarm_path).replace(".csv","").split("_")[-1]
acc_motion_upperarm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_upperarm.columns
]

# --- Combine ---
proband14 = pd.concat(
    [
        gyro_motion_waist, 
        acc_motion_waist, 
        gyro_motion_forearm, 
        acc_motion_forearm,
        gyro_motion_head,
        acc_motion_head,
        gyro_motion_chest,
        acc_motion_chest,
        gyro_motion_shin,
        acc_motion_shin,
        gyro_motion_upperarm,
        acc_motion_upperarm],
        axis=1)

# drop id/time
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

# uppercase
proband14.columns = proband14.columns.str.upper()

# waist -> pelvis
proband14.columns = proband14.columns.str.replace("WAIST", "PELVIS", regex=False)
proband14.columns = proband14.columns.str.replace("CHEST", "TRUNK", regex=False)
proband14.columns = proband14.columns.str.replace("SHIN", "SHANK", regex=False)

# drop id/time again (not necessary, but harmless)
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

proband14
# Out:
#        PELVIS_GYR_X  PELVIS_GYR_Y  PELVIS_GYR_Z  PELVIS_ACC_X  PELVIS_ACC_Y  \
# 0          0.063915     -0.050569      0.123514      9.765948     -0.834379
# 1          0.057501     -0.053012      0.121071      9.859921     -0.903213
# 2          0.048338     -0.064619      0.118627      9.850345     -0.930746
# 3          0.047422     -0.054540      0.122598      9.818023     -0.860715
# 4          0.048338     -0.049653      0.127790      9.706693     -0.871489
# ...             ...           ...           ...           ...           ...
# 76394           NaN           NaN           NaN           NaN           NaN
# 76395           NaN           NaN           NaN           NaN           NaN
# 76396           NaN           NaN           NaN           NaN           NaN
# 76397           NaN           NaN           NaN           NaN           NaN
# 76398           NaN           NaN           NaN           NaN           NaN
#
# ...

# %%
import os, json
import pandas as pd
DATA_PATH_csv=os.path.join(
    BOX_ROOT,
    "WHT Datasets",
    "01_columns_synced",
    "RealWorldHAR",
    "PROBAND 14")

output_path = os.path.join(DATA_PATH_csv, "walking.csv")
proband14.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: /Users/aprillin/Library/CloudStorage/Box-Box/WHT Datasets/01_columns_synced/RealWorldHAR/PROBAND 14/walking.csv

# %%
# --- Gyroscope waist ---
gyro_motion_waist_path = os.path.join(DATA_PATH, "Gyroscope_running_waist.csv")
gyro_motion_waist = pd.read_csv(gyro_motion_waist_path)
gyro_suffix = os.path.basename(gyro_motion_waist_path).replace(".csv","").split("_")[-1]
gyro_motion_waist.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_waist.columns
]

# --- Accelerometer waist ---
acc_motion_waist_path = os.path.join(DATA_PATH, "acc_running_waist.csv")
acc_motion_waist = pd.read_csv(acc_motion_waist_path)
acc_suffix = os.path.basename(acc_motion_waist_path).replace(".csv","").split("_")[-1]
acc_motion_waist.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_waist.columns
]

# --- Gyroscope forearm ---
gyro_motion_forearm_path = os.path.join(DATA_PATH, "Gyroscope_running_forearm.csv")
gyro_motion_forearm = pd.read_csv(gyro_motion_forearm_path)
gyro_suffix = os.path.basename(gyro_motion_forearm_path).replace(".csv","").split("_")[-1]
gyro_motion_forearm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_forearm.columns
]

# --- Accelerometer forearm ---
acc_motion_forearm_path = os.path.join(DATA_PATH, "acc_running_forearm.csv")
acc_motion_forearm = pd.read_csv(acc_motion_forearm_path)
acc_suffix = os.path.basename(acc_motion_forearm_path).replace(".csv","").split("_")[-1]
acc_motion_forearm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_forearm.columns
]

# --- Gyroscope head ---
gyro_motion_head_path = os.path.join(DATA_PATH, "Gyroscope_running_head.csv")
gyro_motion_head = pd.read_csv(gyro_motion_head_path)
gyro_suffix = os.path.basename(gyro_motion_head_path).replace(".csv","").split("_")[-1]
gyro_motion_head.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_head.columns
]

# --- Accelerometer head ---
acc_motion_head_path = os.path.join(DATA_PATH, "acc_running_head.csv")
acc_motion_head = pd.read_csv(acc_motion_head_path)
acc_suffix = os.path.basename(acc_motion_head_path).replace(".csv","").split("_")[-1]
acc_motion_head.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_head.columns
]

# --- Gyroscope chest ---
gyro_motion_chest_path = os.path.join(DATA_PATH, "Gyroscope_running_chest.csv")
gyro_motion_chest = pd.read_csv(gyro_motion_chest_path)
gyro_suffix = os.path.basename(gyro_motion_chest_path).replace(".csv","").split("_")[-1]
gyro_motion_chest.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_chest.columns
]

# --- Accelerometer forearm ---
acc_motion_chest_path = os.path.join(DATA_PATH, "acc_running_chest.csv")
acc_motion_chest = pd.read_csv(acc_motion_chest_path)
acc_suffix = os.path.basename(acc_motion_chest_path).replace(".csv","").split("_")[-1]
acc_motion_chest.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_chest.columns
]

# --- Gyroscope shin ---
gyro_motion_shin_path = os.path.join(DATA_PATH, "Gyroscope_running_shin.csv")
gyro_motion_shin = pd.read_csv(gyro_motion_shin_path)
gyro_suffix = os.path.basename(gyro_motion_shin_path).replace(".csv","").split("_")[-1]
gyro_motion_shin.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_shin.columns
]

# --- Accelerometer shin ---
acc_motion_shin_path = os.path.join(DATA_PATH, "acc_running_shin.csv")
acc_motion_shin = pd.read_csv(acc_motion_shin_path)
acc_suffix = os.path.basename(acc_motion_shin_path).replace(".csv","").split("_")[-1]
acc_motion_shin.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_shin.columns
]

# --- Gyroscope upperearm ---
gyro_motion_upperarm_path = os.path.join(DATA_PATH, "Gyroscope_running_upperarm.csv")
gyro_motion_upperarm = pd.read_csv(gyro_motion_upperarm_path)
gyro_suffix = os.path.basename(gyro_motion_upperarm_path).replace(".csv","").split("_")[-1]
gyro_motion_upperarm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_upperarm.columns
]

# --- Accelerometer upperarm ---
acc_motion_upperarm_path = os.path.join(DATA_PATH, "acc_running_upperarm.csv")
acc_motion_upperarm = pd.read_csv(acc_motion_upperarm_path)
acc_suffix = os.path.basename(acc_motion_upperarm_path).replace(".csv","").split("_")[-1]
acc_motion_upperarm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_upperarm.columns
]

# --- Combine ---
proband14 = pd.concat(
    [
        gyro_motion_waist, 
        acc_motion_waist, 
        gyro_motion_forearm, 
        acc_motion_forearm,
        gyro_motion_head,
        acc_motion_head,
        gyro_motion_chest,
        acc_motion_chest,
        gyro_motion_shin,
        acc_motion_shin,
        gyro_motion_upperarm,
        acc_motion_upperarm],
        axis=1)

# drop id/time
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

# uppercase
proband14.columns = proband14.columns.str.upper()

# waist -> pelvis
proband14.columns = proband14.columns.str.replace("WAIST", "PELVIS", regex=False)
proband14.columns = proband14.columns.str.replace("CHEST", "TRUNK", regex=False)
proband14.columns = proband14.columns.str.replace("SHIN", "SHANK", regex=False)

# drop id/time again (not necessary, but harmless)
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

proband14
# Out:
#        PELVIS_GYR_X  PELVIS_GYR_Y  PELVIS_GYR_Z  PELVIS_ACC_X  PELVIS_ACC_Y  \
# 0         -0.033850     -0.051432     -0.022961     10.061034      0.122104
# 1         -0.037515     -0.081670     -0.019601     10.126875      0.022745
# 2         -0.029268     -0.085641     -0.027542     10.071808     -0.031723
# 3         -0.013386     -0.066704     -0.023571      9.934141      0.041899
# 4         -0.004223     -0.030663     -0.016241      9.842564      0.183755
# ...             ...           ...           ...           ...           ...
# 31414           NaN           NaN           NaN           NaN           NaN
# 31415           NaN           NaN           NaN           NaN           NaN
# 31416           NaN           NaN           NaN           NaN           NaN
# 31417           NaN           NaN           NaN           NaN           NaN
# 31418           NaN           NaN           NaN           NaN           NaN
#
# ...

# %%
output_path = os.path.join(DATA_PATH_csv, "running.csv")
proband14.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: /Users/aprillin/Library/CloudStorage/Box-Box/WHT Datasets/01_columns_synced/RealWorldHAR/PROBAND 14/running.csv

# %%
BOX_ROOT = os.path.expanduser("~/Library/CloudStorage/Box-Box")
DATA_PATH=os.path.join(
    BOX_ROOT,
    "WHT Datasets",
    "00_raw",
    "RealWorldHAR",
    "realworld2016_dataset",
    "proband13",
    "data")
# --- Gyroscope waist ---
gyro_motion_waist_path = os.path.join(DATA_PATH, "Gyroscope_standing_waist.csv")
gyro_motion_waist = pd.read_csv(gyro_motion_waist_path)
gyro_suffix = os.path.basename(gyro_motion_waist_path).replace(".csv","").split("_")[-1]
gyro_motion_waist.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_waist.columns
]

# --- Accelerometer waist ---
acc_motion_waist_path = os.path.join(DATA_PATH, "acc_standing_waist.csv")
acc_motion_waist = pd.read_csv(acc_motion_waist_path)
acc_suffix = os.path.basename(acc_motion_waist_path).replace(".csv","").split("_")[-1]
acc_motion_waist.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_waist.columns
]

# --- Gyroscope forearm ---
gyro_motion_forearm_path = os.path.join(DATA_PATH, "Gyroscope_standing_forearm.csv")
gyro_motion_forearm = pd.read_csv(gyro_motion_forearm_path)
gyro_suffix = os.path.basename(gyro_motion_forearm_path).replace(".csv","").split("_")[-1]
gyro_motion_forearm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_forearm.columns
]

# --- Accelerometer forearm ---
acc_motion_forearm_path = os.path.join(DATA_PATH, "acc_standing_forearm.csv")
acc_motion_forearm = pd.read_csv(acc_motion_forearm_path)
acc_suffix = os.path.basename(acc_motion_forearm_path).replace(".csv","").split("_")[-1]
acc_motion_forearm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_forearm.columns
]

# --- Gyroscope head ---
gyro_motion_head_path = os.path.join(DATA_PATH, "Gyroscope_standing_head.csv")
gyro_motion_head = pd.read_csv(gyro_motion_head_path)
gyro_suffix = os.path.basename(gyro_motion_head_path).replace(".csv","").split("_")[-1]
gyro_motion_head.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_head.columns
]

# --- Accelerometer head ---
acc_motion_head_path = os.path.join(DATA_PATH, "acc_standing_head.csv")
acc_motion_head = pd.read_csv(acc_motion_head_path)
acc_suffix = os.path.basename(acc_motion_head_path).replace(".csv","").split("_")[-1]
acc_motion_head.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_head.columns
]

# --- Gyroscope chest ---
gyro_motion_chest_path = os.path.join(DATA_PATH, "Gyroscope_standing_chest.csv")
gyro_motion_chest = pd.read_csv(gyro_motion_chest_path)
gyro_suffix = os.path.basename(gyro_motion_chest_path).replace(".csv","").split("_")[-1]
gyro_motion_chest.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_chest.columns
]

# --- Accelerometer forearm ---
acc_motion_chest_path = os.path.join(DATA_PATH, "acc_standing_chest.csv")
acc_motion_chest = pd.read_csv(acc_motion_chest_path)
acc_suffix = os.path.basename(acc_motion_chest_path).replace(".csv","").split("_")[-1]
acc_motion_chest.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_chest.columns
]

# --- Gyroscope shin ---
gyro_motion_shin_path = os.path.join(DATA_PATH, "Gyroscope_standing_shin.csv")
gyro_motion_shin = pd.read_csv(gyro_motion_shin_path)
gyro_suffix = os.path.basename(gyro_motion_shin_path).replace(".csv","").split("_")[-1]
gyro_motion_shin.columns  = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_shin.columns
]

# --- Accelerometer shin ---
acc_motion_shin_path = os.path.join(DATA_PATH, "acc_standing_shin.csv")
acc_motion_shin = pd.read_csv(acc_motion_shin_path)
acc_suffix = os.path.basename(acc_motion_shin_path).replace(".csv","").split("_")[-1]
acc_motion_shin.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_shin.columns
]

# --- Gyroscope upperearm ---
gyro_motion_upperarm_path = os.path.join(DATA_PATH, "Gyroscope_standing_upperarm.csv")
gyro_motion_upperarm = pd.read_csv(gyro_motion_upperarm_path)
gyro_suffix = os.path.basename(gyro_motion_upperarm_path).replace(".csv","").split("_")[-1]
gyro_motion_upperarm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_upperarm.columns
]

# --- Accelerometer upperarm ---
acc_motion_upperarm_path = os.path.join(DATA_PATH, "acc_standing_upperarm.csv")
acc_motion_upperarm = pd.read_csv(acc_motion_upperarm_path)
acc_suffix = os.path.basename(acc_motion_upperarm_path).replace(".csv","").split("_")[-1]
acc_motion_upperarm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_upperarm.columns
]

# --- Combine ---
proband13 = pd.concat(
    [
        gyro_motion_waist, 
        acc_motion_waist, 
        gyro_motion_forearm, 
        acc_motion_forearm,
        gyro_motion_head,
        acc_motion_head,
        gyro_motion_chest,
        acc_motion_chest,
        gyro_motion_shin,
        acc_motion_shin,
        gyro_motion_upperarm,
        acc_motion_upperarm],
        axis=1)

# drop id/time
proband13 = proband13.loc[:, ~proband13.columns.str.contains("id|time", case=False, regex=True)]

# uppercase
proband13.columns = proband13.columns.str.upper()

# waist -> pelvis
proband13.columns = proband13.columns.str.replace("WAIST", "PELVIS", regex=False)
proband13.columns = proband13.columns.str.replace("CHEST", "TRUNK", regex=False)
proband13.columns = proband13.columns.str.replace("SHIN", "SHANK", regex=False)

# drop id/time again (not necessary, but harmless)
proband13 = proband13.loc[:, ~proband13.columns.str.contains("id|time", case=False, regex=True)]

proband13

import os, json
import pandas as pd
DATA_PATH_csv=os.path.join(
    BOX_ROOT,
    "WHT Datasets",
    "01_columns_synced",
    "RealWorldHAR",
    "PROBAND 13")

output_path = os.path.join(DATA_PATH_csv, "standing.csv")
proband13.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: /Users/aprillin/Library/CloudStorage/Box-Box/WHT Datasets/01_columns_synced/RealWorldHAR/PROBAND 13/standing.csv

# %%
# --- Gyroscope waist ---
gyro_motion_waist_path = os.path.join(DATA_PATH, "Gyroscope_sitting_waist.csv")
gyro_motion_waist = pd.read_csv(gyro_motion_waist_path)
gyro_suffix = os.path.basename(gyro_motion_waist_path).replace(".csv","").split("_")[-1]
gyro_motion_waist.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_waist.columns
]

# --- Accelerometer waist ---
acc_motion_waist_path = os.path.join(DATA_PATH, "acc_sitting_waist.csv")
acc_motion_waist = pd.read_csv(acc_motion_waist_path)
acc_suffix = os.path.basename(acc_motion_waist_path).replace(".csv","").split("_")[-1]
acc_motion_waist.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_waist.columns
]

# --- Gyroscope forearm ---
gyro_motion_forearm_path = os.path.join(DATA_PATH, "Gyroscope_sitting_forearm.csv")
gyro_motion_forearm = pd.read_csv(gyro_motion_forearm_path)
gyro_suffix = os.path.basename(gyro_motion_forearm_path).replace(".csv","").split("_")[-1]
gyro_motion_forearm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_forearm.columns
]

# --- Accelerometer forearm ---
acc_motion_forearm_path = os.path.join(DATA_PATH, "acc_sitting_forearm.csv")
acc_motion_forearm = pd.read_csv(acc_motion_forearm_path)
acc_suffix = os.path.basename(acc_motion_forearm_path).replace(".csv","").split("_")[-1]
acc_motion_forearm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_forearm.columns
]

# --- Gyroscope head ---
gyro_motion_head_path = os.path.join(DATA_PATH, "Gyroscope_sitting_head.csv")
gyro_motion_head = pd.read_csv(gyro_motion_head_path)
gyro_suffix = os.path.basename(gyro_motion_head_path).replace(".csv","").split("_")[-1]
gyro_motion_head.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_head.columns
]

# --- Accelerometer head ---
acc_motion_head_path = os.path.join(DATA_PATH, "acc_sitting_head.csv")
acc_motion_head = pd.read_csv(acc_motion_head_path)
acc_suffix = os.path.basename(acc_motion_head_path).replace(".csv","").split("_")[-1]
acc_motion_head.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_head.columns
]

# --- Gyroscope chest ---
gyro_motion_chest_path = os.path.join(DATA_PATH, "Gyroscope_sitting_chest.csv")
gyro_motion_chest = pd.read_csv(gyro_motion_chest_path)
gyro_suffix = os.path.basename(gyro_motion_chest_path).replace(".csv","").split("_")[-1]
gyro_motion_chest.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_chest.columns
]

# --- Accelerometer forearm ---
acc_motion_chest_path = os.path.join(DATA_PATH, "acc_sitting_chest.csv")
acc_motion_chest = pd.read_csv(acc_motion_chest_path)
acc_suffix = os.path.basename(acc_motion_chest_path).replace(".csv","").split("_")[-1]
acc_motion_chest.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_chest.columns
]

# --- Gyroscope shin ---
gyro_motion_shin_path = os.path.join(DATA_PATH, "Gyroscope_sitting_shin.csv")
gyro_motion_shin = pd.read_csv(gyro_motion_shin_path)
gyro_suffix = os.path.basename(gyro_motion_shin_path).replace(".csv","").split("_")[-1]
gyro_motion_shin.columns  = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_shin.columns
]

# --- Accelerometer shin ---
acc_motion_shin_path = os.path.join(DATA_PATH, "acc_sitting_shin.csv")
acc_motion_shin = pd.read_csv(acc_motion_shin_path)
acc_suffix = os.path.basename(acc_motion_shin_path).replace(".csv","").split("_")[-1]
acc_motion_shin.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_shin.columns
]

# --- Gyroscope upperearm ---
gyro_motion_upperarm_path = os.path.join(DATA_PATH, "Gyroscope_sitting_upperarm.csv")
gyro_motion_upperarm = pd.read_csv(gyro_motion_upperarm_path)
gyro_suffix = os.path.basename(gyro_motion_upperarm_path).replace(".csv","").split("_")[-1]
gyro_motion_upperarm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_upperarm.columns
]

# --- Accelerometer upperarm ---
acc_motion_upperarm_path = os.path.join(DATA_PATH, "acc_sitting_upperarm.csv")
acc_motion_upperarm = pd.read_csv(acc_motion_upperarm_path)
acc_suffix = os.path.basename(acc_motion_upperarm_path).replace(".csv","").split("_")[-1]
acc_motion_upperarm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_upperarm.columns
]

# --- Combine ---
proband14 = pd.concat(
    [
        gyro_motion_waist, 
        acc_motion_waist, 
        gyro_motion_forearm, 
        acc_motion_forearm,
        gyro_motion_head,
        acc_motion_head,
        gyro_motion_chest,
        acc_motion_chest,
        gyro_motion_shin,
        acc_motion_shin,
        gyro_motion_upperarm,
        acc_motion_upperarm],
        axis=1)

# drop id/time
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

# uppercase
proband14.columns = proband14.columns.str.upper()

# waist -> pelvis
proband14.columns = proband14.columns.str.replace("WAIST", "PELVIS", regex=False)
proband14.columns = proband14.columns.str.replace("CHEST", "TRUNK", regex=False)
proband14.columns = proband14.columns.str.replace("SHIN", "SHANK", regex=False)

# drop id/time again (not necessary, but harmless)
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

proband14

import os, json
import pandas as pd
DATA_PATH_csv=os.path.join(
    BOX_ROOT,
    "WHT Datasets",
    "01_columns_synced",
    "RealWorldHAR",
    "PROBAND 14")

output_path = os.path.join(DATA_PATH_csv, "sitting.csv")
proband14.to_csv(output_path, index=False)

print("Saved to:", output_path)
proband14.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: /Users/aprillin/Library/CloudStorage/Box-Box/WHT Datasets/01_columns_synced/RealWorldHAR/PROBAND 14/sitting.csv
# Saved to: /Users/aprillin/Library/CloudStorage/Box-Box/WHT Datasets/01_columns_synced/RealWorldHAR/PROBAND 14/sitting.csv

# %%
# --- Gyroscope waist ---
gyro_motion_waist_path = os.path.join(DATA_PATH, "Gyroscope_lying_waist.csv")
gyro_motion_waist = pd.read_csv(gyro_motion_waist_path)
gyro_suffix = os.path.basename(gyro_motion_waist_path).replace(".csv","").split("_")[-1]
gyro_motion_waist.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_waist.columns
]

# --- Accelerometer waist ---
acc_motion_waist_path = os.path.join(DATA_PATH, "acc_lying_waist.csv")
acc_motion_waist = pd.read_csv(acc_motion_waist_path)
acc_suffix = os.path.basename(acc_motion_waist_path).replace(".csv","").split("_")[-1]
acc_motion_waist.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_waist.columns
]

# --- Gyroscope forearm ---
gyro_motion_forearm_path = os.path.join(DATA_PATH, "Gyroscope_lying_forearm.csv")
gyro_motion_forearm = pd.read_csv(gyro_motion_forearm_path)
gyro_suffix = os.path.basename(gyro_motion_forearm_path).replace(".csv","").split("_")[-1]
gyro_motion_forearm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_forearm.columns
]

# --- Accelerometer forearm ---
acc_motion_forearm_path = os.path.join(DATA_PATH, "acc_lying_forearm.csv")
acc_motion_forearm = pd.read_csv(acc_motion_forearm_path)
acc_suffix = os.path.basename(acc_motion_forearm_path).replace(".csv","").split("_")[-1]
acc_motion_forearm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_forearm.columns
]

# --- Gyroscope head ---
gyro_motion_head_path = os.path.join(DATA_PATH, "Gyroscope_lying_head.csv")
gyro_motion_head = pd.read_csv(gyro_motion_head_path)
gyro_suffix = os.path.basename(gyro_motion_head_path).replace(".csv","").split("_")[-1]
gyro_motion_head.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_head.columns
]

# --- Accelerometer head ---
acc_motion_head_path = os.path.join(DATA_PATH, "acc_lying_head.csv")
acc_motion_head = pd.read_csv(acc_motion_head_path)
acc_suffix = os.path.basename(acc_motion_head_path).replace(".csv","").split("_")[-1]
acc_motion_head.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_head.columns
]

# --- Gyroscope chest ---
gyro_motion_chest_path = os.path.join(DATA_PATH, "Gyroscope_lying_chest.csv")
gyro_motion_chest = pd.read_csv(gyro_motion_chest_path)
gyro_suffix = os.path.basename(gyro_motion_chest_path).replace(".csv","").split("_")[-1]
gyro_motion_chest.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_chest.columns
]

# --- Accelerometer forearm ---
acc_motion_chest_path = os.path.join(DATA_PATH, "acc_lying_chest.csv")
acc_motion_chest = pd.read_csv(acc_motion_chest_path)
acc_suffix = os.path.basename(acc_motion_chest_path).replace(".csv","").split("_")[-1]
acc_motion_chest.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_chest.columns
]

# --- Gyroscope shin ---
gyro_motion_shin_path = os.path.join(DATA_PATH, "Gyroscope_lying_shin.csv")
gyro_motion_shin = pd.read_csv(gyro_motion_shin_path)
gyro_suffix = os.path.basename(gyro_motion_shin_path).replace(".csv","").split("_")[-1]
gyro_motion_shin.columns  = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_shin.columns
]

# --- Accelerometer shin ---
acc_motion_shin_path = os.path.join(DATA_PATH, "acc_lying_shin.csv")
acc_motion_shin = pd.read_csv(acc_motion_shin_path)
acc_suffix = os.path.basename(acc_motion_shin_path).replace(".csv","").split("_")[-1]
acc_motion_shin.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_shin.columns
]

# --- Gyroscope upperearm ---
gyro_motion_upperarm_path = os.path.join(DATA_PATH, "Gyroscope_lying_upperarm.csv")
gyro_motion_upperarm = pd.read_csv(gyro_motion_upperarm_path)
gyro_suffix = os.path.basename(gyro_motion_upperarm_path).replace(".csv","").split("_")[-1]
gyro_motion_upperarm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_upperarm.columns
]

# --- Accelerometer upperarm ---
acc_motion_upperarm_path = os.path.join(DATA_PATH, "acc_lying_upperarm.csv")
acc_motion_upperarm = pd.read_csv(acc_motion_upperarm_path)
acc_suffix = os.path.basename(acc_motion_upperarm_path).replace(".csv","").split("_")[-1]
acc_motion_upperarm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_upperarm.columns
]

# --- Combine ---
proband14 = pd.concat(
    [
        gyro_motion_waist, 
        acc_motion_waist, 
        gyro_motion_forearm, 
        acc_motion_forearm,
        gyro_motion_head,
        acc_motion_head,
        gyro_motion_chest,
        acc_motion_chest,
        gyro_motion_shin,
        acc_motion_shin,
        gyro_motion_upperarm,
        acc_motion_upperarm],
        axis=1)

# drop id/time
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

# uppercase
proband14.columns = proband14.columns.str.upper()

# waist -> pelvis
proband14.columns = proband14.columns.str.replace("WAIST", "PELVIS", regex=False)
proband14.columns = proband14.columns.str.replace("CHEST", "TRUNK", regex=False)
proband14.columns = proband14.columns.str.replace("SHIN", "SHANK", regex=False)

# drop id/time again (not necessary, but harmless)
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

proband14


output_path = os.path.join(DATA_PATH_csv, "lying.csv")
proband14.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: /Users/aprillin/Library/CloudStorage/Box-Box/WHT Datasets/01_columns_synced/RealWorldHAR/PROBAND 14/lying.csv

# %%
# --- Gyroscope waist ---
gyro_motion_waist_path = os.path.join(DATA_PATH, "Gyroscope_jumping_waist.csv")
gyro_motion_waist = pd.read_csv(gyro_motion_waist_path)
gyro_suffix = os.path.basename(gyro_motion_waist_path).replace(".csv","").split("_")[-1]
gyro_motion_waist.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_waist.columns
]

# --- Accelerometer waist ---
acc_motion_waist_path = os.path.join(DATA_PATH, "acc_jumping_waist.csv")
acc_motion_waist = pd.read_csv(acc_motion_waist_path)
acc_suffix = os.path.basename(acc_motion_waist_path).replace(".csv","").split("_")[-1]
acc_motion_waist.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_waist.columns
]

# --- Gyroscope forearm ---
gyro_motion_forearm_path = os.path.join(DATA_PATH, "Gyroscope_jumping_forearm.csv")
gyro_motion_forearm = pd.read_csv(gyro_motion_forearm_path)
gyro_suffix = os.path.basename(gyro_motion_forearm_path).replace(".csv","").split("_")[-1]
gyro_motion_forearm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_forearm.columns
]

# --- Accelerometer forearm ---
acc_motion_forearm_path = os.path.join(DATA_PATH, "acc_jumping_forearm.csv")
acc_motion_forearm = pd.read_csv(acc_motion_forearm_path)
acc_suffix = os.path.basename(acc_motion_forearm_path).replace(".csv","").split("_")[-1]
acc_motion_forearm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_forearm.columns
]

# --- Gyroscope head ---
gyro_motion_head_path = os.path.join(DATA_PATH, "Gyroscope_jumping_head.csv")
gyro_motion_head = pd.read_csv(gyro_motion_head_path)
gyro_suffix = os.path.basename(gyro_motion_head_path).replace(".csv","").split("_")[-1]
gyro_motion_head.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_head.columns
]

# --- Accelerometer head ---
acc_motion_head_path = os.path.join(DATA_PATH, "acc_jumping_head.csv")
acc_motion_head = pd.read_csv(acc_motion_head_path)
acc_suffix = os.path.basename(acc_motion_head_path).replace(".csv","").split("_")[-1]
acc_motion_head.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_head.columns
]

# --- Gyroscope chest ---
gyro_motion_chest_path = os.path.join(DATA_PATH, "Gyroscope_jumping_chest.csv")
gyro_motion_chest = pd.read_csv(gyro_motion_chest_path)
gyro_suffix = os.path.basename(gyro_motion_chest_path).replace(".csv","").split("_")[-1]
gyro_motion_chest.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_chest.columns
]

# --- Accelerometer forearm ---
acc_motion_chest_path = os.path.join(DATA_PATH, "acc_jumping_chest.csv")
acc_motion_chest = pd.read_csv(acc_motion_chest_path)
acc_suffix = os.path.basename(acc_motion_chest_path).replace(".csv","").split("_")[-1]
acc_motion_chest.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_chest.columns
]

# --- Gyroscope shin ---
gyro_motion_shin_path = os.path.join(DATA_PATH, "Gyroscope_jumping_shin.csv")
gyro_motion_shin = pd.read_csv(gyro_motion_shin_path)
gyro_suffix = os.path.basename(gyro_motion_shin_path).replace(".csv","").split("_")[-1]
gyro_motion_shin.columns  = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_shin.columns
]

# --- Accelerometer shin ---
acc_motion_shin_path = os.path.join(DATA_PATH, "acc_jumping_shin.csv")
acc_motion_shin = pd.read_csv(acc_motion_shin_path)
acc_suffix = os.path.basename(acc_motion_shin_path).replace(".csv","").split("_")[-1]
acc_motion_shin.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_shin.columns
]

# --- Gyroscope upperearm ---
gyro_motion_upperarm_path = os.path.join(DATA_PATH, "Gyroscope_jumping_upperarm.csv")
gyro_motion_upperarm = pd.read_csv(gyro_motion_upperarm_path)
gyro_suffix = os.path.basename(gyro_motion_upperarm_path).replace(".csv","").split("_")[-1]
gyro_motion_upperarm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_upperarm.columns
]

# --- Accelerometer upperarm ---
acc_motion_upperarm_path = os.path.join(DATA_PATH, "acc_jumping_upperarm.csv")
acc_motion_upperarm = pd.read_csv(acc_motion_upperarm_path)
acc_suffix = os.path.basename(acc_motion_upperarm_path).replace(".csv","").split("_")[-1]
acc_motion_upperarm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_upperarm.columns
]

# --- Combine ---
proband14 = pd.concat(
    [
        gyro_motion_waist, 
        acc_motion_waist, 
        gyro_motion_forearm, 
        acc_motion_forearm,
        gyro_motion_head,
        acc_motion_head,
        gyro_motion_chest,
        acc_motion_chest,
        gyro_motion_shin,
        acc_motion_shin,
        gyro_motion_upperarm,
        acc_motion_upperarm],
        axis=1)

# drop id/time
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

# uppercase
proband14.columns = proband14.columns.str.upper()

# waist -> pelvis
proband14.columns = proband14.columns.str.replace("WAIST", "PELVIS", regex=False)
proband14.columns = proband14.columns.str.replace("CHEST", "TRUNK", regex=False)
proband14.columns = proband14.columns.str.replace("SHIN", "SHANK", regex=False)

# drop id/time again (not necessary, but harmless)
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

proband14


output_path = os.path.join(DATA_PATH_csv, "jumping.csv")
proband14.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: /Users/aprillin/Library/CloudStorage/Box-Box/WHT Datasets/01_columns_synced/RealWorldHAR/PROBAND 14/jumping.csv

# %%
# --- Gyroscope waist ---
gyro_motion_waist_path = os.path.join(DATA_PATH, "Gyroscope_climbingup_waist.csv")
gyro_motion_waist = pd.read_csv(gyro_motion_waist_path)
gyro_suffix = os.path.basename(gyro_motion_waist_path).replace(".csv","").split("_")[-1]
gyro_motion_waist.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_waist.columns
]

# --- Accelerometer waist ---
acc_motion_waist_path = os.path.join(DATA_PATH, "acc_climbingup_waist.csv")
acc_motion_waist = pd.read_csv(acc_motion_waist_path)
acc_suffix = os.path.basename(acc_motion_waist_path).replace(".csv","").split("_")[-1]
acc_motion_waist.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_waist.columns
]

# --- Gyroscope forearm ---
gyro_motion_forearm_path = os.path.join(DATA_PATH, "Gyroscope_climbingup_forearm.csv")
gyro_motion_forearm = pd.read_csv(gyro_motion_forearm_path)
gyro_suffix = os.path.basename(gyro_motion_forearm_path).replace(".csv","").split("_")[-1]
gyro_motion_forearm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_forearm.columns
]

# --- Accelerometer forearm ---
acc_motion_forearm_path = os.path.join(DATA_PATH, "acc_climbingup_forearm.csv")
acc_motion_forearm = pd.read_csv(acc_motion_forearm_path)
acc_suffix = os.path.basename(acc_motion_forearm_path).replace(".csv","").split("_")[-1]
acc_motion_forearm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_forearm.columns
]

# --- Gyroscope head ---
gyro_motion_head_path = os.path.join(DATA_PATH, "Gyroscope_climbingup_head.csv")
gyro_motion_head = pd.read_csv(gyro_motion_head_path)
gyro_suffix = os.path.basename(gyro_motion_head_path).replace(".csv","").split("_")[-1]
gyro_motion_head.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_head.columns
]

# --- Accelerometer head ---
acc_motion_head_path = os.path.join(DATA_PATH, "acc_climbingup_head.csv")
acc_motion_head = pd.read_csv(acc_motion_head_path)
acc_suffix = os.path.basename(acc_motion_head_path).replace(".csv","").split("_")[-1]
acc_motion_head.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_head.columns
]

# --- Gyroscope chest ---
gyro_motion_chest_path = os.path.join(DATA_PATH, "Gyroscope_climbingup_chest.csv")
gyro_motion_chest = pd.read_csv(gyro_motion_chest_path)
gyro_suffix = os.path.basename(gyro_motion_chest_path).replace(".csv","").split("_")[-1]
gyro_motion_chest.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_chest.columns
]

# --- Accelerometer forearm ---
acc_motion_chest_path = os.path.join(DATA_PATH, "acc_climbingup_chest.csv")
acc_motion_chest = pd.read_csv(acc_motion_chest_path)
acc_suffix = os.path.basename(acc_motion_chest_path).replace(".csv","").split("_")[-1]
acc_motion_chest.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_chest.columns
]

# --- Gyroscope shin ---
gyro_motion_shin_path = os.path.join(DATA_PATH, "Gyroscope_climbingup_shin.csv")
gyro_motion_shin = pd.read_csv(gyro_motion_shin_path)
gyro_suffix = os.path.basename(gyro_motion_shin_path).replace(".csv","").split("_")[-1]
gyro_motion_shin.columns  = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_shin.columns
]

# --- Accelerometer shin ---
acc_motion_shin_path = os.path.join(DATA_PATH, "acc_climbingup_shin.csv")
acc_motion_shin = pd.read_csv(acc_motion_shin_path)
acc_suffix = os.path.basename(acc_motion_shin_path).replace(".csv","").split("_")[-1]
acc_motion_shin.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_shin.columns
]

# --- Gyroscope upperearm ---
gyro_motion_upperarm_path = os.path.join(DATA_PATH, "Gyroscope_climbingup_upperarm.csv")
gyro_motion_upperarm = pd.read_csv(gyro_motion_upperarm_path)
gyro_suffix = os.path.basename(gyro_motion_upperarm_path).replace(".csv","").split("_")[-1]
gyro_motion_upperarm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_upperarm.columns
]

# --- Accelerometer upperarm ---
acc_motion_upperarm_path = os.path.join(DATA_PATH, "acc_climbingup_upperarm.csv")
acc_motion_upperarm = pd.read_csv(acc_motion_upperarm_path)
acc_suffix = os.path.basename(acc_motion_upperarm_path).replace(".csv","").split("_")[-1]
acc_motion_upperarm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_upperarm.columns
]

# --- Combine ---
proband14 = pd.concat(
    [
        gyro_motion_waist, 
        acc_motion_waist, 
        gyro_motion_forearm, 
        acc_motion_forearm,
        gyro_motion_head,
        acc_motion_head,
        gyro_motion_chest,
        acc_motion_chest,
        gyro_motion_shin,
        acc_motion_shin,
        gyro_motion_upperarm,
        acc_motion_upperarm],
        axis=1)

# drop id/time
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

# uppercase
proband14.columns = proband14.columns.str.upper()

# waist -> pelvis
proband14.columns = proband14.columns.str.replace("WAIST", "PELVIS", regex=False)
proband14.columns = proband14.columns.str.replace("CHEST", "TRUNK", regex=False)
proband14.columns = proband14.columns.str.replace("SHIN", "SHANK", regex=False)

# drop id/time again (not necessary, but harmless)
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

proband14


output_path = os.path.join(DATA_PATH_csv, "climbingup.csv")
proband14.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: /Users/aprillin/Library/CloudStorage/Box-Box/WHT Datasets/01_columns_synced/RealWorldHAR/PROBAND 14/climbingup.csv

# %%
# --- Gyroscope waist ---
gyro_motion_waist_path = os.path.join(DATA_PATH, "Gyroscope_climbingdown_waist.csv")
gyro_motion_waist = pd.read_csv(gyro_motion_waist_path)
gyro_suffix = os.path.basename(gyro_motion_waist_path).replace(".csv","").split("_")[-1]
gyro_motion_waist.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_waist.columns
]

# --- Accelerometer waist ---
acc_motion_waist_path = os.path.join(DATA_PATH, "acc_climbingdown_waist.csv")
acc_motion_waist = pd.read_csv(acc_motion_waist_path)
acc_suffix = os.path.basename(acc_motion_waist_path).replace(".csv","").split("_")[-1]
acc_motion_waist.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_waist.columns
]

# --- Gyroscope forearm ---
gyro_motion_forearm_path = os.path.join(DATA_PATH, "Gyroscope_climbingdown_forearm.csv")
gyro_motion_forearm = pd.read_csv(gyro_motion_forearm_path)
gyro_suffix = os.path.basename(gyro_motion_forearm_path).replace(".csv","").split("_")[-1]
gyro_motion_forearm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_forearm.columns
]

# --- Accelerometer forearm ---
acc_motion_forearm_path = os.path.join(DATA_PATH, "acc_climbingdown_forearm.csv")
acc_motion_forearm = pd.read_csv(acc_motion_forearm_path)
acc_suffix = os.path.basename(acc_motion_forearm_path).replace(".csv","").split("_")[-1]
acc_motion_forearm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_forearm.columns
]

# --- Gyroscope head ---
gyro_motion_head_path = os.path.join(DATA_PATH, "Gyroscope_climbingdown_head.csv")
gyro_motion_head = pd.read_csv(gyro_motion_head_path)
gyro_suffix = os.path.basename(gyro_motion_head_path).replace(".csv","").split("_")[-1]
gyro_motion_head.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_head.columns
]

# --- Accelerometer head ---
acc_motion_head_path = os.path.join(DATA_PATH, "acc_climbingdown_head.csv")
acc_motion_head = pd.read_csv(acc_motion_head_path)
acc_suffix = os.path.basename(acc_motion_head_path).replace(".csv","").split("_")[-1]
acc_motion_head.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_head.columns
]

# --- Gyroscope chest ---
gyro_motion_chest_path = os.path.join(DATA_PATH, "Gyroscope_climbingdown_chest.csv")
gyro_motion_chest = pd.read_csv(gyro_motion_chest_path)
gyro_suffix = os.path.basename(gyro_motion_chest_path).replace(".csv","").split("_")[-1]
gyro_motion_chest.columns = [
    f"{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_chest.columns
]

# --- Accelerometer forearm ---
acc_motion_chest_path = os.path.join(DATA_PATH, "acc_climbingdown_chest.csv")
acc_motion_chest = pd.read_csv(acc_motion_chest_path)
acc_suffix = os.path.basename(acc_motion_chest_path).replace(".csv","").split("_")[-1]
acc_motion_chest.columns = [
    f"{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_chest.columns
]

# --- Gyroscope shin ---
gyro_motion_shin_path = os.path.join(DATA_PATH, "Gyroscope_climbingdown_shin.csv")
gyro_motion_shin = pd.read_csv(gyro_motion_shin_path)
gyro_suffix = os.path.basename(gyro_motion_shin_path).replace(".csv","").split("_")[-1]
gyro_motion_shin.columns  = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_shin.columns
]

# --- Accelerometer shin ---
acc_motion_shin_path = os.path.join(DATA_PATH, "acc_climbingdown_shin.csv")
acc_motion_shin = pd.read_csv(acc_motion_shin_path)
acc_suffix = os.path.basename(acc_motion_shin_path).replace(".csv","").split("_")[-1]
acc_motion_shin.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_shin.columns
]

# --- Gyroscope upperarm ---
gyro_motion_upperarm_path = os.path.join(DATA_PATH, "Gyroscope_climbingdown_upperarm.csv")
gyro_motion_upperarm = pd.read_csv(gyro_motion_upperarm_path)
gyro_suffix = os.path.basename(gyro_motion_upperarm_path).replace(".csv","").split("_")[-1]
gyro_motion_upperarm.columns = [
    f"l_{gyro_suffix}_gyr_{c.replace('attr_', '')}"
    for c in gyro_motion_upperarm.columns
]

# --- Accelerometer upperarm ---
acc_motion_upperarm_path = os.path.join(DATA_PATH, "acc_climbingdown_upperarm.csv")
acc_motion_upperarm = pd.read_csv(acc_motion_upperarm_path)
acc_suffix = os.path.basename(acc_motion_upperarm_path).replace(".csv","").split("_")[-1]
acc_motion_upperarm.columns = [
    f"l_{acc_suffix}_acc_{c.replace('attr_', '')}"
    for c in acc_motion_upperarm.columns
]

# --- Combine ---
proband14 = pd.concat(
    [
        gyro_motion_waist, 
        acc_motion_waist, 
        gyro_motion_forearm, 
        acc_motion_forearm,
        gyro_motion_head,
        acc_motion_head,
        gyro_motion_chest,
        acc_motion_chest,
        gyro_motion_shin,
        acc_motion_shin,
        gyro_motion_upperarm,
        acc_motion_upperarm],
        axis=1)

# drop id/time
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

# uppercase
proband14.columns = proband14.columns.str.upper()

# waist -> pelvis
proband14.columns = proband14.columns.str.replace("WAIST", "PELVIS", regex=False)
proband14.columns = proband14.columns.str.replace("CHEST", "TRUNK", regex=False)
proband14.columns = proband14.columns.str.replace("SHIN", "SHANK", regex=False)

# drop id/time again (not necessary, but harmless)
proband14 = proband14.loc[:, ~proband14.columns.str.contains("id|time", case=False, regex=True)]

proband14


output_path = os.path.join(DATA_PATH_csv, "climbingdown.csv")
proband14.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: /Users/aprillin/Library/CloudStorage/Box-Box/WHT Datasets/01_columns_synced/RealWorldHAR/PROBAND 14/climbingdown.csv
